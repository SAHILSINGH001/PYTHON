# %% [markdown]
# <h1>TASK2 </h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
height = np.random.normal(140, 20, 1000)
plt.figure(dpi=200)
plt.title("Height distribution")
plt.xlabel("Height(cm)")
plt.ylabel("Frequency")
plt.hist(height, bins=30, ec="white")
# Out:
# (array([ 1.,  0.,  1.,  2.,  5.,  1.,  8., 17., 27., 18., 42., 42., 48.,
#         60., 64., 69., 67., 99., 86., 70., 74., 57., 54., 26., 27., 15.,
#         10.,  3.,  4.,  3.]),
#  array([ 67.81204566,  72.12542044,  76.43879522,  80.75217001,
#          85.06554479,  89.37891957,  93.69229435,  98.00566914,
#         102.31904392, 106.6324187 , 110.94579348, 115.25916827,
#         119.57254305, 123.88591783, 128.19929262, 132.5126674 ,
#         136.82604218, 141.13941696, 145.45279175, 149.76616653,
#         154.07954131, 158.39291609, 162.70629088, 167.01966566,
#         171.33304044, 175.64641523, 179.95979001, 184.27316479,
#         188.58653957, 192.89991436, 197.21328914]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# <h4>Difference between interpreter and compiler?</h4>
#
# Compiler considers the entire program as a whole and translates the entire source code in one run whereas Interpreter translates the source code line by line

# %% [markdown]
# <h4>What is Data Structure, why we need one in programs?</h4>
#
# Data structures is a way to organise data stored in a computer in an efficient manner such that the retrival and storage of data from those structures becomes easy.

# %% [markdown]
# <h1>TASK 3</h1>

# %% [markdown]
# <h4>What are Data Structures? List some of data structures and their use in real world application?</h4>
#
# Data Structures are a way to store, retrieve, and manipulate/rearrange data in an efficient way so that it becomes easy to refer to a set of data easily.
#
# Set
# Lists
# Dictionary
# Tuples
# Frozenset
# int
# float
# String

# %% [markdown]
# <h2>Create a list data type and store names of your friends in it (at least 5), check out what are methods available in list data type, try to figure out their working using help function in python.</h2>

# %%
list1=["hello","welcome","to","python"]

# %%
help(list1)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
list2=list1.copy()
print(list2)
# Out:
# ['hello', 'welcome', 'to', 'python']

# %%
list1.insert(2, "java")
print(list1)
# Out:
# ['hello', 'welcome', 'java', 'to', 'java', 'python']

# %%
print(list1.pop())
# Out:
# python

# %% [markdown]
# <h4> What is difference between ordered data type and unordered data type?</h4>
#
# Ordered datatype means that the elements of the datatype have a particular order and the elements should be inserted in that order only for a desired output. Ordered datatypes can be sorted and have inbuilt functions to sort them. Eg.: Lists in Python.
#
# Unordered datatype means that the elements of the datatype can be inserted in any order. Eg.: Dictionary

# %% [markdown]
# <h4>Write down types of each value given? (In python)</h4>
#
# 100 -> int
#
# 105.5 -> float
#
# 192.56j -> complex
#
# 10+6j -> complex
#
# ‘10’ -> str
#
# ‘Hello world’ -> str
#
# [10, 20, 50, 100] -> list
#
# {‘name’: ‘sachin’, ‘age’: 24, ‘language’: ‘python’} -> Dictionary
